# %%
import pandas as pd
df = pd.read_table("data/data.txt",sep="\t")
print(df.shape)
df.head(20)
# Out:
# (222, 28)
#     Time Time Code         Country Name Country Code  \
# 0   2013    YR2013          Afghanistan          AFG
# 1   2013    YR2013              Albania          ALB
# 2   2013    YR2013              Algeria          DZA
# 3   2013    YR2013       American Samoa          ASM
# 4   2013    YR2013              Andorra          AND
# 5   2013    YR2013               Angola          AGO
# 6   2013    YR2013  Antigua and Barbuda          ATG
# 7   2013    YR2013            Argentina          ARG
# 8   2013    YR2013              Armenia          ARM
# 9   2013    YR2013                Aruba          ABW
# 10  2013    YR2013            Australia          AUS
# 11  2013    YR2013              Austria          AUT
# 12  2013    YR2013           Azerbaijan          AZE
# 13  2013    YR2013         Bahamas, The          BHS
# 14  2013    YR2013              Bahrain          BHR
# 15  2013    YR2013           Bangladesh          BGD
# ...

# %%
columnsNamesArr = df.columns.values
# convert ndarray to list
listOfColumnNames = list(columnsNamesArr)
listOfColumnNames
# Out:
# ['Time',
#  'Time Code',
#  'Country Name',
#  'Country Code',
#  'Alternative and nuclear energy (% of total energy use) [EG.USE.COMM.CL.ZS]',
#  'Armed forces personnel (% of total labor force) [MS.MIL.TOTL.TF.ZS]',
#  'Arms exports (SIPRI trend indicator values) [MS.MIL.XPRT.KD]',
#  'Central government debt, total (% of GDP) [GC.DOD.TOTL.GD.ZS]',
#  'Children out of school (% of primary school age) [SE.PRM.UNER.ZS]',
#  'CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]',
#  'GDP per capita (current US$) [NY.GDP.PCAP.CD]',
#  'GINI index (World Bank estimate) [SI.POV.GINI]',
#  'Income share held by highest 10% [SI.DST.10TH.10]',
#  'International migrant stock (% of population) [SM.POP.TOTL.ZS]',
#  'International tourism, number of arrivals [ST.INT.ARVL]',
#  'Land area (sq. km) [AG.LND.TOTL.K2]',
#  'Life expectancy at birth, total (years) [SP.DYN.LE00.IN]',
#  'Net migration [SM.POP.NETM]',
#  'Physicians (per 1,000 people) [SH.MED.PHYS.ZS]',
# ...

# %%
df.isna().sum()
# Out:
# Time                                                                                                          3
# Time Code                                                                                                     5
# Country Name                                                                                                  5
# Country Code                                                                                                  5
# Alternative and nuclear energy (% of total energy use) [EG.USE.COMM.CL.ZS]                                   81
# Armed forces personnel (% of total labor force) [MS.MIL.TOTL.TF.ZS]                                          56
# Arms exports (SIPRI trend indicator values) [MS.MIL.XPRT.KD]                                                181
# Central government debt, total (% of GDP) [GC.DOD.TOTL.GD.ZS]                                               169
# ...

# %%
df.isna().sum()
# Out:
# Time                                                                                                          3
# Time Code                                                                                                     5
# Country Name                                                                                                  5
# Country Code                                                                                                  5
# Alternative and nuclear energy (% of total energy use) [EG.USE.COMM.CL.ZS]                                   81
# Armed forces personnel (% of total labor force) [MS.MIL.TOTL.TF.ZS]                                          56
# Arms exports (SIPRI trend indicator values) [MS.MIL.XPRT.KD]                                                181
# Central government debt, total (% of GDP) [GC.DOD.TOTL.GD.ZS]                                               169
# ...

# %%
df2=df.drop(["Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant) [SP.MTR.1519.ZS]"],axis=1)
df2.head()
# Out:
#    Time Time Code    Country Name Country Code  \
# 0  2013    YR2013     Afghanistan          AFG
# 1  2013    YR2013         Albania          ALB
# 2  2013    YR2013         Algeria          DZA
# 3  2013    YR2013  American Samoa          ASM
# 4  2013    YR2013         Andorra          AND
#
#    Alternative and nuclear energy (% of total energy use) [EG.USE.COMM.CL.ZS]  \
# 0                                                NaN
# 1                                          26.068785
# 2                                           0.042983
# 3                                                NaN
# 4                                                NaN
#
#    Armed forces personnel (% of total labor force) [MS.MIL.TOTL.TF.ZS]  \
# 0                                           2.971228
# 1                                           0.682812
# 2                                           2.641161
# 3                                                NaN
# ...

# %%
df.head()
# Out:
#    Time Time Code    Country Name Country Code  \
# 0  2013    YR2013     Afghanistan          AFG
# 1  2013    YR2013         Albania          ALB
# 2  2013    YR2013         Algeria          DZA
# 3  2013    YR2013  American Samoa          ASM
# 4  2013    YR2013         Andorra          AND
#
#    Alternative and nuclear energy (% of total energy use) [EG.USE.COMM.CL.ZS]  \
# 0                                                NaN
# 1                                          26.068785
# 2                                           0.042983
# 3                                                NaN
# 4                                                NaN
#
#    Armed forces personnel (% of total labor force) [MS.MIL.TOTL.TF.ZS]  \
# 0                                           2.971228
# 1                                           0.682812
# 2                                           2.641161
# 3                                                NaN
# ...
